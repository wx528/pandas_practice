# %%
import numpy as np
import pandas as pd

# 测试 Numpy
arr = np.array([1, 2, 3])
print(f"Numpy Array: {arr}")

# 测试 Pandas
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
print("Pandas DataFrame:")
print(df)
# Out:
# Numpy Array: [1 2 3]
# Pandas DataFrame:
#    A  B
# 0  1  3
# 1  2  4
